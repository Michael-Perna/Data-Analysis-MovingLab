# %%
from import_df import NmeaDf
import swiss_projection
import numpy as np
import pandas as pd

# %%
def degmin2deg(degmin):
    a, b = str(degmin).split('.')
    d = int(a[:-2])
    m = float(a[-2:] + '.'+ b)

    degrees = d + m/60
    #rad = degrees*180/np.pi
    return degrees

# %%
# dataframe with the coordinates
filepath = "../2021/January/29/swipos_NetR9.nmea"
timeseries = NmeaDf(filepath)
df = timeseries.getDataFrame()

# Drop rows where there is no coordinates
df = df.dropna(subset=['lat', 'lon']).reset_index(drop=True)

# %%
# Out:
#                   timestamp time  lon  stdLong  lat  stdLat  alt  stdAlt  sep  \
# 0      2021-01-28T23:59:15Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 1      2021-01-28T23:59:16Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 2      2021-01-28T23:59:17Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 3      2021-01-28T23:59:18Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 4      2021-01-28T23:59:19Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# ...                     ...  ...  ...      ...  ...     ...  ...     ...  ...
# 72745  2021-01-30T00:00:08Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 72746  2021-01-30T00:00:09Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 72747  2021-01-30T00:00:10Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 72748  2021-01-30T00:00:11Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
# 72749  2021-01-30T00:00:12Z  nan  NaN      NaN  NaN     NaN  NaN     NaN  NaN
#
#        rangeRMS  ... posModeGB difAgeGB opMode navMode  PDOP HDOP VDOP  \
# 0           NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 1           NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 2           NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 3           NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 4           NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# ...         ...  ...       ...      ...    ...     ...   ...  ...  ...
# 72745       NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 72746       NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 72747       NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 72748       NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
# 72749       NaN  ...       nan      NaN      A  No Fix   NaN  NaN  NaN
#
#        stdMajor stdMinor orient
# 0           NaN      NaN    NaN
# 1           NaN      NaN    NaN
# 2           NaN      NaN    NaN
# 3           NaN      NaN    NaN
# 4           NaN      NaN    NaN
# ...         ...      ...    ...
# 72745       NaN      NaN    NaN
# 72746       NaN      NaN    NaN
# 72747       NaN      NaN    NaN
# 72748       NaN      NaN    NaN
# 72749       NaN      NaN    NaN
#
# [72750 rows x 32 columns]

# %%
df.loc[:,'lon'] = df.loc[:,'lon'].apply(degmin2deg)
df.loc[:,'lat'] = df.loc[:,'lat'].apply(degmin2deg)
df.loc[:, ['lon', 'lat', 'alt']] = df.loc[:, ['lon', 'lat', 'alt']].apply(swiss_projection.wgs84_to_lv95)

# %%
df
# Out:
#          lat    lon
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 72745  False  False
# 72746  False  False
# 72747  False  False
# 72748  False  False
# 72749  False  False
#
# [72750 rows x 2 columns]

# %%
df
# Out:
#                   timestamp time           lon  stdLong           lat  \
# 0      2021-01-29T06:11:41Z  nan  2.409028e+06    1.097  5.478162e+06
# 1      2021-01-29T06:11:42Z  nan -3.758096e+06    1.037  1.826829e+06
# 2      2021-01-29T06:11:43Z  nan  3.365984e+01    1.020  1.281578e+02
# 3      2021-01-29T06:11:44Z  nan           NaN    1.016           NaN
# 4      2021-01-29T06:11:45Z  nan           NaN    1.001           NaN
# ...                     ...  ...           ...      ...           ...
# 48367  2021-01-29T19:17:25Z  nan           NaN    3.912           NaN
# 48368  2021-01-29T19:17:26Z  nan           NaN    4.353           NaN
# 48369  2021-01-29T19:17:27Z  nan           NaN    4.911           NaN
# 48370  2021-01-29T19:17:28Z  nan           NaN    4.502           NaN
# 48371  2021-01-29T19:17:29Z  nan           NaN   84.363           NaN
#
#         stdLat           alt   stdAlt      sep  rangeRMS  ... posModeGB  \
# 0        1.240  1.664076e+06    2.452  397.649     1.385  ...       nan
# 1        1.173 -4.410486e+06    2.318  397.653     1.295  ...       nan
# 2        1.154  5.639505e+01    2.280  397.582     1.263  ...       nan
# 3        1.149           NaN    2.271  397.537     1.254  ...       nan
# 4        1.131           NaN    2.235  397.486     1.229  ...       nan
# ...        ...           ...      ...      ...       ...  ...       ...
# 48367    5.343           NaN   11.109  390.064     6.655  ...       nan
# 48368   10.672           NaN    9.489  369.213     5.862  ...         A
# 48369   10.552           NaN    6.466  376.927     2.443  ...       nan
# 48370   15.939           NaN   18.327  373.823     5.434  ...       nan
# 48371  143.774           NaN  295.187  302.998     0.000  ...       nan
#
#       difAgeGB opMode                navMode   PDOP HDOP  VDOP  stdMajor  \
# 0          NaN      A  Differential GNSS fix   81.0  NaN  66.0     1.506
# 1          NaN      A  Differential GNSS fix   81.0  NaN  66.0     1.424
# 2          NaN      A  Differential GNSS fix   81.0  NaN  66.0     1.401
# 3          NaN      A  Differential GNSS fix   81.0  NaN  66.0     1.395
# 4          NaN      A  Differential GNSS fix   81.0  NaN  66.0     1.374
# ...        ...    ...                    ...    ...  ...   ...       ...
# 48367      NaN      A  Differential GNSS fix   85.0  NaN   NaN     5.394
# 48368      NaN      A  Differential GNSS fix  127.0  NaN   NaN    11.041
# 48369      NaN      A  Differential GNSS fix   68.0  NaN   NaN    11.258
# 48370      NaN      A  Differential GNSS fix   68.0  NaN   NaN    15.940
# 48371      NaN      A  Differential GNSS fix   68.0  NaN   NaN   146.992
#
#       stdMinor orient
# 0        0.688  140.4
# 1        0.651  140.4
# 2        0.640  140.4
# 3        0.637  140.4
# 4        0.628  140.4
# ...        ...    ...
# 48367    3.841  168.7
# 48368    3.306  164.4
# 48369    2.954  158.8
# 48370    4.499  179.4
# 48371   78.622   14.3
#
# [48372 rows x 32 columns]

# %%
# Dataframe to matrix
lon =  pd.DataFrame(df['lon']).to_numpy()
lat =  pd.DataFrame(df['lat']).to_numpy()
alt =  pd.DataFrame(df['alt']).to_numpy()

# Creation of a matrix len(lat) x 3
#llh = np.concatenate((lon,lat,alt), axis=1)
# Converstion to lv95
lv95 = np.zeros((len(lon),3)) # Pre-allocate matrix
for i in range(len(alt)):
    # Convert in degree (nmea format)
    llh = [degmin2deg(lon[i].tolist()[0]), degmin2deg(lat[i].tolist()[0]), alt[i].tolist()[0]]
    
    lv95[i, :] = swiss_projection.wgs84_to_lv95(llh)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-eb1a958db6bc> in <module>
#      10 for i in range(len(alt)):
#      11     # Convert in degree (nmea format)
# ---> 12     llh = [degmin2deg(lon[i].tolist()[0]), degmin2deg(lat[i].tolist()[0]), alt[i].tolist()[0]]
#      13
#      14     lv95[i, :] = swiss_projection.wgs84_to_lv95(llh)
#
# <ipython-input-2-0f284af48dd9> in degmin2deg(degmin)
#       1 def degmin2deg(degmin):
#       2     a, b = str(degmin).split('.')
# ----> 3     d = int(a[:-2])
#       4     m = float(a[-2:] + '.'+ b)
#       5
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# save the dataframe as a csv file 
df.to_csv("../tracks/sapcorda.csv")
